# %% [markdown]
# <a href="https://colab.research.google.com/github/Guthikonda-Akshaya/GanForge/blob/main/guthikonda_akshaya_240420_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import cv2
from glob import glob


cat_images = glob('/content/cats_and_dogs_filtered/train/cats/*.jpg')
dog_images = glob('/content/cats_and_dogs_filtered/train/dogs/*.jpg')

if cat_images and dog_images:
    cat_img = mpimg.imread(cat_images[0])
    dog_img = mpimg.imread(dog_images[0])

    # Display
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    axes[0].imshow(cat_img)
    axes[0].set_title("Cat")
    axes[0].axis('off')

    axes[1].imshow(dog_img)
    axes[1].set_title("Dog")
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print(" No images found. Please check the paths.")

# %% [markdown]
# # New Section

# %%
#Image Manipulation
img=plt.imread(dog_images [2])
fig, axes = plt.subplots(figsize=(8, 8))
axes.imshow(img)
axes.axis('off')
plt.show()

# %%
import cv2

# %%
cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Out:
# array([[[133, 191, 173],
#         [183, 241, 223],
#         [142, 200, 182],
#         ...,
#         [196, 211, 220],
#         [143, 155, 165],
#         [158, 167, 177]],
#
#        [[161, 219, 201],
#         [190, 248, 230],
#         [152, 210, 192],
#         ...,
#         [179, 191, 201],
#         [179, 189, 199],
#         [151, 160, 170]],
#
#        [[179, 237, 219],
#         [187, 245, 227],
#         [167, 226, 211],
#         ...,
#         [160, 170, 180],
#         [180, 189, 199],
#         [185, 191, 202]],
#
#        ...,
#
#        [[100, 115, 118],
#         [108, 114, 119],
#         [135, 127, 134],
#         ...,
#         [ 92, 116, 104],
#         [ 95, 121, 107],
#         [109, 138, 122]],
#
#        [[109, 130, 131],
#         [114, 126, 128],
#         [140, 129, 137],
#         ...,
#         [ 69,  91,  79],
#         [ 73, 100,  84],
#         [ 92, 119, 103]],
#
#        [[121, 142, 143],
#         [121, 133, 135],
#         [140, 129, 137],
#         ...,
#         [ 54,  76,  64],
#         [ 62,  89,  73],
#         [ 85, 112,  96]]], dtype=uint8)

# %%
import cv2

# %%
#resizing
img_resize=cv2.resize(img, None,fx=0.50,fy=0.50)
fig, axes = plt.subplots(figsize=(8, 8))
axes.imshow(img_resize)
axes.axis('off')
plt.show()

# %%
import cv2

# %%
#resizing
img_resize=cv2.resize(img,(100,200), interpolation = cv2.INTER_CUBIC)
fig, axes = plt.subplots(figsize=(8, 8))
axes.imshow(img_resize)
axes.axis('off')
axes.set_title('resized photo')
plt.show()

# %%
 #sharpening image
import numpy as np
import cv2
image_sharpen = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
sharpened = cv2.filter2D(img, -1, image_sharpen)
fig, axes = plt.subplots(figsize=(8, 8))
axes.imshow(sharpened)
axes.axis('off')
axes.set_title('Sharpened photo')
plt.show()

# %%
import cv2

# %%
#blurring image
image_3x3 = np.ones((3, 3), dtype=np.float32) / 8.0
blurred = cv2.filter2D(img, -1, image_3x3)
fig, axes = plt.subplots(figsize=(8, 8))
axes.imshow(blurred)
axes.axis('off')
axes.set_title('Blurred photo')
plt.show()

# %% [markdown]
# # New Section
